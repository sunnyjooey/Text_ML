# %% [markdown]
# ### Random Forest, In-depth

# %%
import proto
import classifier
from sklearn.ensemble import RandomForestClassifier

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
feat_types = {
    'PROTO, SMALL': 'proto_small',
    'PROTO, LARGE, Large': 'proto_large', 
    'TOPICS, SMALL': 'topic_small', 
    'TOPICS, LARGE': 'topic_large', 
    'SENTIMENTS, SMALL': 'sentim_small',
    'SENTIMENTS, LARGE': 'sentim_large',
    'ALL FEATURES': 'all_features'
        }

clf = RandomForestClassifier(n_estimators=10, n_jobs=-1)

# %%
# Run models on different groups of features
obj = classifier.run_ensemble(feat_types, clf, True, 20)
# Out:
# PROTO, SMALL
#             AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.845746           0.786851     0.15101   0.805982  0.933455
# r      0.845746           0.809076     0.15101   0.913635  0.758037
# Feature ranking:
# 1. feature PROTO_HT_SCORE_r (0.495723)
# 2. feature rncincle (0.263189)
# 3. feature PROTO_WORD_SCORE_d (0.047749)
# 4. feature PROTO_WORD_SCORE_r (0.032146)
# 5. feature dncinphl (0.029097)
# 6. feature PROTO_HT_SCORE_d (0.017480)
# 7. feature gopconvention (0.015201)
# 8. feature rnc (0.014552)
# 9. feature gop (0.009246)
# 10. feature dncleak (0.007426)
# 11. feature trump (0.005206)
# 12. feature rnc2016 (0.004530)
# 13. feature cleveland (0.004186)
# 14. feature americafirst (0.003696)
# 15. feature hillaryclinton (0.003191)
# 16. feature trumppence16 (0.003155)
# 17. feature ccot (0.002265)
# 18. feature hillary (0.002061)
# 19. feature makeamericaworkagain (0.001981)
# 20. feature gopincle (0.001883)
# PROTO, LARGE, Large
#             AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.891349           0.880586    0.111899   0.957240  0.823145
# r      0.891349           0.817066    0.111899   0.831434  0.959553
# Feature ranking:
# 1. feature PROTO_HT_SCORE_d (0.346165)
# 2. feature demsinphilly (0.188016)
# 3. feature PROTO_WORD_SCORE_d (0.161524)
# 4. feature PROTO_WORD_SCORE_r (0.051924)
# 5. feature demconvention (0.049143)
# 6. feature dnc (0.032182)
# 7. feature democratic (0.012137)
# 8. feature sanders (0.009187)
# 9. feature PROTO_HT_SCORE_r (0.008647)
# 10. feature dncinphl (0.008505)
# 11. feature cruz (0.005270)
# 12. feature cleveland (0.005117)
# 13. feature imwithher (0.004970)
# 14. feature kaine (0.004899)
# 15. feature melania_x (0.004853)
# 16. feature bernie (0.004637)
# 17. feature feelthebern (0.003186)
# 18. feature debbie (0.002798)
# 19. feature americafirst (0.002779)
# 20. feature christie (0.002665)
# TOPICS, SMALL
#             AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.712473           0.674618    0.286305   0.727514  0.733527
# r      0.712473           0.627879    0.286305   0.697898  0.691420
# Feature ranking:
# 1. feature topic_25 (0.076027)
# 2. feature topic_19 (0.042455)
# 3. feature topic_30 (0.039308)
# 4. feature topic_12 (0.033650)
# 5. feature topic_28 (0.028929)
# 6. feature topic_36 (0.027744)
# 7. feature topic_33 (0.027325)
# 8. feature topic_2 (0.026139)
# 9. feature topic_16 (0.022886)
# 10. feature topic_13 (0.022761)
# 11. feature topic_10 (0.021686)
# 12. feature topic_27 (0.021675)
# 13. feature topic_40 (0.021565)
# 14. feature topic_44 (0.021338)
# 15. feature topic_14 (0.020649)
# 16. feature topic_35 (0.020536)
# 17. feature topic_20 (0.019697)
# 18. feature topic_34 (0.019357)
# 19. feature topic_24 (0.018866)
# 20. feature topic_7 (0.018507)
# TOPICS, LARGE
#            AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.71777           0.674180    0.281697   0.730464  0.729803
# r      0.71777           0.638184    0.281697   0.705040  0.705737
# Feature ranking:
# 1. feature topic_87 (0.067039)
# 2. feature topic_50 (0.037645)
# 3. feature topic_25 (0.031484)
# 4. feature topic_41 (0.030847)
# 5. feature topic_79 (0.028189)
# 6. feature topic_8 (0.025117)
# 7. feature topic_37 (0.020475)
# 8. feature topic_23 (0.017358)
# 9. feature topic_49 (0.016598)
# 10. feature topic_97 (0.016290)
# 11. feature topic_56 (0.015664)
# 12. feature topic_48 (0.015468)
# 13. feature topic_88 (0.015370)
# 14. feature topic_4 (0.015185)
# 15. feature topic_95 (0.014427)
# 16. feature topic_1 (0.014335)
# 17. feature topic_61 (0.013980)
# 18. feature topic_3 (0.013196)
# 19. feature topic_98 (0.012930)
# 20. feature topic_51 (0.012848)
# SENTIMENTS, SMALL
#             AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.537616           0.540665    0.470046   0.580894  0.342883
# r      0.537616           0.500164    0.470046   0.507414  0.732349
# Feature ranking:
# 1. feature r_POSITIVE (0.119435)
# 2. feature sent_! (0.092632)
# 3. feature d_POSITIVE (0.084782)
# 4. feature r_NEGATIVE (0.071350)
# 5. feature d_NEGATIVE (0.060963)
# 6. feature sent_hillaryclinton (0.032163)
# 7. feature sent_’ (0.023807)
# 8. feature sent_her (0.023540)
# 9. feature sent_watch (0.019263)
# 10. feature sent_republican (0.017801)
# 11. feature sent_… (0.014762)
# 12. feature sent_let (0.012363)
# 13. feature sent_democrats (0.011358)
# 14. feature sent_today (0.010643)
# 15. feature sent_american (0.010529)
# 16. feature sent_woman (0.010073)
# 17. feature sent_campaign (0.009882)
# 18. feature sent_https… (0.008803)
# 19. feature sent_kaine (0.008765)
# 20. feature sent_news (0.008347)
# SENTIMENTS, LARGE
#             AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.517828           0.522275    0.482217   0.530917  0.516122
# r      0.517828           0.496176    0.482217   0.504715  0.519534
# Feature ranking:
# 1. feature r_POSITIVE (0.104133)
# 2. feature sent_https (0.081765)
# 3. feature r_NEGATIVE (0.066523)
# 4. feature d_POSITIVE (0.056936)
# 5. feature d_NEGATIVE (0.049814)
# 6. feature sent_dnc (0.049719)
# 7. feature sent_you (0.025768)
# 8. feature sent_'s (0.023796)
# 9. feature sent_convention (0.019741)
# 10. feature sent_speech (0.015779)
# 11. feature sent_hillaryclinton (0.014367)
# 12. feature sent_cleveland (0.013617)
# 13. feature sent_rnc (0.013021)
# 14. feature sent_cruz (0.011496)
# 15. feature sent_america (0.010521)
# 16. feature sent_she (0.009437)
# 17. feature sent_us (0.008828)
# 18. feature sent_one (0.008715)
# 19. feature sent_her (0.008356)
# 20. feature sent_me (0.007871)
# ALL FEATURES
#             AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.898953           0.875753     0.10221   0.926032  0.874887
# r      0.898953           0.839735     0.10221   0.870084  0.923020
# Feature ranking:
# 1. feature demsinphilly (0.216442)
# 2. feature PROTO_HT_SCORE_d (0.159783)
# 3. feature PROTO_WORD_SCORE_d (0.071682)
# 4. feature PROTO_WORD_SCORE_r (0.034811)
# 5. feature demconvention (0.026983)
# 6. feature democratic (0.020801)
# 7. feature topic_17 (0.019946)
# 8. feature dnc (0.014417)
# 9. feature topic_2 (0.013510)
# 10. feature dncinphl (0.013310)
# 11. feature topic_22 (0.010747)
# 12. feature r_POSITIVE (0.009917)
# 13. feature topic_16 (0.009333)
# 14. feature topic_36 (0.007776)
# 15. feature topic_30 (0.007699)
# 16. feature sent_! (0.007662)
# 17. feature topic_11 (0.007338)
# 18. feature topic_3 (0.006895)
# 19. feature topic_6 (0.006590)
# 20. feature topic_38 (0.006520)
