# %% [markdown]
# ### Random Forest, In-depth

# %%
import proto
import classifier
from sklearn.ensemble import RandomForestClassifier

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
feat_types = {
    'PROTO, SMALL': 'proto_small',
    'PROTO, LARGE, Large': 'proto_large', 
    'TOPICS, SMALL': 'topic_small', 
    'TOPICS, LARGE': 'topic_large', 
    'SENTIMENTS, SMALL': 'sentim_small',
    'SENTIMENTS, LARGE': 'sentim_large',
    'ALL FEATURES': 'all_features'
        }

clf = RandomForestClassifier(n_estimators=100, n_jobs=-1)

# %%
# Run models on different groups of features
obj = classifier.run_ensemble(feat_types, clf, True, 20)
# Out:
# PROTO, SMALL
#             AUC  Average_Precision  Error_Rate  Precision    Recall
# Label
# d      0.845211           0.786533    0.151601   0.806273  0.931404
# r      0.845211           0.807739    0.151601   0.911314  0.759018
# Feature ranking:
# 1. feature PROTO_HT_SCORE_r (0.456647)
# 2. feature rncincle (0.291401)
# 3. feature gopconvention (0.032924)
# 4. feature PROTO_WORD_SCORE_d (0.032379)
# 5. feature PROTO_WORD_SCORE_r (0.030282)
# 6. feature dncinphl (0.019364)
# 7. feature PROTO_HT_SCORE_d (0.018893)
# 8. feature rnc (0.018018)
# 9. feature gop (0.010892)
# 10. feature dncleak (0.010111)
# 11. feature ccot (0.006044)
# 12. feature trump (0.005311)
# 13. feature cleveland (0.004452)
# 14. feature trumppence16 (0.003962)
# 15. feature rnc2016 (0.003706)
# 16. feature americafirst (0.003638)
# 17. feature hillaryclinton (0.002982)
# 18. feature rncinc (0.002138)
# 19. feature melaniatrump (0.002074)
# 20. feature biden (0.001822)
# PROTO, LARGE, Large
# ...
